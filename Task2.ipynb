# %% [markdown]
# <a href="https://colab.research.google.com/github/Piyush23510/elevate-lab-Task--1-Data-cleaning-and-Preprocessing/blob/main/Task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task 2: Exploratory Data Analysis on Titanic Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv("/content/Titanic_Cleaned.csv")

print("First 5 rows:")
print(df.head())

print("\nDataset shape:")
print(df.shape)

print("\nDataset info:")
print(df.info())

print("\nMissing values:")
print(df.isnull().sum())

print("\nSummary statistics:")
print(df.describe())

print("\nMedian values:")
print(df.median(numeric_only=True))

print("\nMode values:")
print(df.mode().iloc[0])

# Create folder manually named: screenshots or outputs before running if needed

# 1. Histograms for numeric columns
numeric_cols = df.select_dtypes(include=["int64", "float64"]).columns

df[numeric_cols].hist(figsize=(12, 8), bins=20)
plt.suptitle("Histograms of Numeric Features")
plt.tight_layout()
plt.savefig("histograms.png")
plt.show()

# 2. Boxplots for numeric columns
plt.figure(figsize=(12, 6))
sns.boxplot(data=df[numeric_cols])
plt.title("Boxplots of Numeric Features")
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("boxplots.png")
plt.show()

# 3. Correlation matrix
plt.figure(figsize=(10, 6))
corr = df[numeric_cols].corr()
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix")
plt.tight_layout()
plt.savefig("correlation_matrix.png")
plt.show()

# 4. Pairplot
sns.pairplot(df[["Survived", "Pclass", "Age", "SibSp", "Parch", "Fare"]].dropna(), hue="Survived")
plt.savefig("pairplot.png")
plt.show()

# 5. Survival count
plt.figure(figsize=(6, 4))
sns.countplot(x="Survived", data=df)
plt.title("Survival Count")
plt.savefig("survival_count.png")
plt.show()

# 6. Survival by gender
plt.figure(figsize=(6, 4))
sns.countplot(x="Sex", hue="Survived", data=df)
plt.title("Survival by Gender")
plt.savefig("survival_by_gender.png")
plt.show()

# 7. Survival by passenger class
plt.figure(figsize=(6, 4))
sns.countplot(x="Pclass", hue="Survived", data=df)
plt.title("Survival by Passenger Class")
plt.savefig("survival_by_class.png")
plt.show()

# 8. Age distribution by survival
plt.figure(figsize=(8, 5))
sns.histplot(data=df, x="Age", hue="Survived", kde=True, bins=30)
plt.title("Age Distribution by Survival")
plt.savefig("age_survival_distribution.png")
plt.show()

# 9. Fare distribution
plt.figure(figsize=(8, 5))
sns.boxplot(x="Survived", y="Fare", data=df)
plt.title("Fare Distribution by Survival")
plt.savefig("fare_survival_boxplot.png")
plt.show()

# Basic inferences
print("\nBasic Inferences:")
print("1. Females had a higher survival rate compared to males.")
print("2. First-class passengers had better survival chances.")
print("3. Fare has outliers, meaning some passengers paid very high ticket prices.")
print("4. Age has missing values and should be handled before ML modeling.")
print("5. Pclass and Fare are related to survival.")
# Out:
# First 5 rows:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            3         1       3
# 2            4         1       1
# 3            5         0       3
# 4            7         0       1
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                       Braund, Mr. Owen Harris    male  22.0      1      0
# 1                        Heikkinen, Miss. Laina  female  26.0      0      0
# 2  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 3                      Allen, Mr. William Henry    male  35.0      0      0
# 4                       McCarthy, Mr. Timothy J    male  54.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1  STON/O2. 3101282   7.9250   NaN        S
# 2            113803  53.1000  C123        S
# 3            373450   8.0500   NaN        S
# 4             17463  51.8625   E46        S
#
# Dataset shape:
# ...
